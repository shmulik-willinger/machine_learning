# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
print (os.path.exists('text8.zip'))
# Out:
# True

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.605608
# Nearest to such: tanenbaum, lina, zoot, depth, estudios, windsurfing, acetic, councilor,
# Nearest to use: yoshi, falco, yew, predominantly, desiderius, suicide, sideband, dwellings,
# Nearest to had: ignore, kaufmann, rattle, carats, ithilien, marginal, keeps, malaysia,
# Nearest to also: positron, quickest, grayson, prescient, insecticides, moldovan, bek, libel,
# Nearest to often: warring, laia, propaganda, unquestionably, supporting, hijacked, florida, subway,
# Nearest to as: get, quincey, cytoskeleton, neurologists, toned, almagest, pbk, caesarion,
# Nearest to states: franchise, times, womb, rosh, xerox, macclesfield, kinetochores, solicitor,
# Nearest to who: brackets, mnp, kilometers, consulted, marlene, sterility, willingness, alligator,
# Nearest to about: peptide, agnostics, silas, apollinaris, evangelistic, subdivide, holdings, represent,
# Nearest to four: dragging, abeda, teletype, midair, shunning, highland, informers, highly,
# Nearest to by: aligned, gbit, roadmap, blanche, heir, punishments, mexicana, structuralism,
# Nearest to has: gynt, repayment, script, macromolecules, satr, conditions, threaded, hypocritical,
# Nearest to the: oriole, poirot, roussimoff, wounding, ynys, logudorese, hologram, menelik,
# Nearest to during: belew, concordat, chanter, comet, robbins, improvisational, bartlett, explained,
# Nearest to to: macmillan, ais, franchised, irish, noises, expiry, pratyeka, miraculous,
# Nearest to have: mumia, multitude, attained, cauca, shandy, extractive, descend, polygon,
# Average loss at step 2000: 4.370277
# Average loss at step 4000: 3.870602
# Average loss at step 6000: 3.789110
# Average loss at step 8000: 3.687324
# Average loss at step 10000: 3.612754
# Nearest to such: known, well, hardship, councilor, envisioned, ergo, zoot, trigonometry,
# Nearest to use: yew, icrc, falco, bang, dwellings, diurnal, sent, battle,
# Nearest to had: has, have, was, ignore, bierce, prince, been, were,
# Nearest to also: not, often, conservationist, been, which, killing, deutscher, positron,
# Nearest to often: also, propaganda, filmfour, undergone, usually, robbing, subway, supper,
# Nearest to as: godless, grotto, daedalus, became, filling, toole, using, patristic,
# Nearest to states: ernie, times, excursion, dead, sarajevo, laureate, crumbled, haven,
# Nearest to who: he, recursive, stallman, which, londoners, baptised, hepatic, and,
# Nearest to about: agnostics, hoppers, quarters, convicted, recite, represent, editors, offending,
# Nearest to four: six, eight, seven, five, three, two, nine, zero,
# Nearest to by: near, was, within, schuschnigg, multilinear, groening, anagrams, been,
# Nearest to has: had, is, have, was, riyadh, theocracy, suck, doctrinal,
# Nearest to the: a, this, its, his, their, shakur, unexpected, mckenna,
# Nearest to during: in, with, tanakh, preprint, concordat, chanter, belew, at,
# Nearest to to: cramer, would, presuppose, noises, not, establishes, unscientific, macmillan,
# Nearest to have: had, has, be, were, are, shandy, teletype, carbohydrates,
# Average loss at step 12000: 3.602040
# Average loss at step 14000: 3.575913
# Average loss at step 16000: 3.408146
# Average loss at step 18000: 3.457931
# Average loss at step 20000: 3.542147
# Nearest to such: known, well, these, other, hardship, councilor, basic, leaf,
# Nearest to use: yew, concept, battle, icrc, orbiter, bang, collection, diurnal,
# Nearest to had: has, have, were, was, since, never, ithilien, youthful,
# Nearest to also: which, often, now, conservationist, who, unlock, peng, not,
# Nearest to often: also, usually, sometimes, filmfour, who, now, dagmar, commonly,
# Nearest to as: grotto, godless, ostensibly, ammonius, lakeshore, for, patristic, pontiff,
# Nearest to states: ernie, excursion, haven, times, indulgence, dead, sarajevo, laureate,
# Nearest to who: he, which, recursive, they, also, and, then, often,
# Nearest to about: convicted, agnostics, hoppers, evangelistic, ross, recite, underlines, editors,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to by: be, stormy, through, for, with, groening, was, in,
# Nearest to has: had, have, was, is, theocracy, dom, having, voluntary,
# Nearest to the: its, their, this, his, an, a, any, another,
# Nearest to during: in, at, with, from, third, after, tanakh, preprint,
# Nearest to to: not, cannot, will, can, may, for, would, could,
# Nearest to have: had, has, were, are, be, mutable, symmetrically, shevat,
# Average loss at step 22000: 3.507635
# Average loss at step 24000: 3.489607
# Average loss at step 26000: 3.481714
# Average loss at step 28000: 3.478348
# Average loss at step 30000: 3.503335
# Nearest to such: well, known, these, other, certain, hardship, basic, many,
# Nearest to use: concept, collection, orbiter, fairs, imitate, chiuchow, yew, diurnal,
# Nearest to had: have, has, was, were, bierce, since, been, having,
# Nearest to also: often, now, it, augusta, generally, never, which, ammo,
# Nearest to often: sometimes, usually, also, commonly, generally, still, now, frequently,
# Nearest to as: ammonius, became, indigo, jagged, godless, grotto, tanganyika, without,
# Nearest to states: excursion, haven, andronicus, deduces, laureate, nations, rabbah, ernie,
# Nearest to who: he, which, they, now, there, often, and, recursive,
# Nearest to about: convicted, agnostics, scratching, hawk, cultivar, ro, editors, wildcat,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to by: was, were, in, theobald, firestone, annuals, anagrams, for,
# Nearest to has: had, have, was, is, since, suck, having, suu,
# Nearest to the: its, their, his, referential, any, moria, many, some,
# Nearest to during: after, at, in, until, aquarium, from, took, cumming,
# Nearest to to: would, could, establishes, can, macmillan, leet, haller, noises,
# Nearest to have: had, has, were, are, be, having, since, do,
# Average loss at step 32000: 3.502418
# Average loss at step 34000: 3.495296
# Average loss at step 36000: 3.457353
# Average loss at step 38000: 3.300997
# Average loss at step 40000: 3.429689
# Nearest to such: well, these, known, including, certain, posts, some, many,
# Nearest to use: fairs, collection, concept, imitate, teleport, orbiter, chiuchow, start,
# Nearest to had: has, have, was, were, bierce, since, been, having,
# Nearest to also: often, now, which, generally, who, still, never, there,
# Nearest to often: usually, sometimes, also, generally, commonly, still, frequently, who,
# Nearest to as: by, indigo, godless, vilna, is, when, be, ammonius,
# Nearest to states: nations, kingdom, indulgence, excursion, andronicus, deduces, ankles, saudi,
# Nearest to who: he, which, also, often, that, she, rower, there,
# Nearest to about: convicted, ro, kristian, agnostics, municipality, hawk, scratching, jeane,
# Nearest to four: six, three, five, two, eight, seven, nine, one,
# Nearest to by: with, as, for, be, was, from, when, is,
# Nearest to has: had, have, is, was, since, suck, riyadh, theocracy,
# Nearest to the: their, its, each, a, this, his, any, pulleys,
# Nearest to during: after, until, at, before, since, in, third, around,
# Nearest to to: cannot, harvey, crafty, leet, must, would, could, noises,
# Nearest to have: had, has, were, are, be, nest, matt, including,
# Average loss at step 42000: 3.436768
# Average loss at step 44000: 3.456842
# Average loss at step 46000: 3.452234
# Average loss at step 48000: 3.355127
# Average loss at step 50000: 3.383643
# Nearest to such: well, these, known, many, including, posts, inhospitable, certain,
# Nearest to use: collection, start, concept, belief, chiuchow, fairs, teleport, imitate,
# Nearest to had: has, have, having, was, were, bierce, been, since,
# Nearest to also: often, now, which, still, generally, never, sometimes, ain,
# Nearest to often: usually, sometimes, generally, commonly, also, frequently, now, still,
# Nearest to as: became, very, downwards, yucat, engraving, expatriate, ammonius, after,
# Nearest to states: kingdom, nations, saudi, deduces, missiles, haven, devices, subtitle,
# Nearest to who: he, which, she, often, they, there, now, also,
# Nearest to about: agnostics, kristian, convicted, underlines, ro, hawk, editors, cobalt,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to by: through, anagrams, gains, stillman, with, wallis, gandhi, under,
# Nearest to has: had, have, was, is, since, having, mug, dom,
# Nearest to the: their, its, his, this, a, mathias, referential, some,
# Nearest to during: after, in, until, before, at, when, from, since,
# Nearest to to: would, will, must, may, ais, connery, can, cannot,
# Nearest to have: had, has, were, be, are, nest, matt, symmetrically,
# Average loss at step 52000: 3.436373
# Average loss at step 54000: 3.431346
# Average loss at step 56000: 3.438429
# Average loss at step 58000: 3.400622
# Average loss at step 60000: 3.395781
# Nearest to such: well, these, known, many, inhospitable, certain, including, heero,
# Nearest to use: concept, collection, fairs, belief, start, teleport, repelling, form,
# Nearest to had: has, have, was, were, having, bierce, been, eritrean,
# Nearest to also: now, often, still, generally, sometimes, never, there, ain,
# Nearest to often: sometimes, usually, commonly, generally, frequently, also, still, now,
# Nearest to as: became, conditioned, multimedia, insecticides, judy, makkah, interpersonal, rover,
# Nearest to states: kingdom, nations, deduces, saudi, haven, countries, state, devices,
# Nearest to who: which, now, he, she, still, often, that, never,
# Nearest to about: convicted, agnostics, kristian, wildcat, ro, underlines, jeane, cynic,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to by: through, asean, wallis, mitotic, gandhi, anagrams, from, schuschnigg,
# Nearest to has: had, have, is, was, having, dom, lobbying, holds,
# Nearest to the: their, a, its, each, any, shakur, this, his,
# Nearest to during: after, in, before, until, at, since, although, counters,
# Nearest to to: shall, would, may, retrospective, coals, establishes, cannot, not,
# Nearest to have: has, had, were, are, be, having, accept, shevat,
# Average loss at step 62000: 3.243915
# Average loss at step 64000: 3.253552
# Average loss at step 66000: 3.404119
# Average loss at step 68000: 3.396739
# Average loss at step 70000: 3.359643
# Nearest to such: these, well, known, many, certain, inhospitable, rehabilitation, including,
# Nearest to use: collection, concept, fairs, most, develop, form, repelling, teleport,
# Nearest to had: have, has, was, were, having, bierce, since, eritrean,
# Nearest to also: now, still, often, never, which, generally, sometimes, commonly,
# Nearest to often: usually, sometimes, commonly, generally, frequently, also, still, now,
# Nearest to as: jagged, insecticides, when, interwoven, is, became, indigo, wizard,
# Nearest to states: kingdom, nations, state, saudi, countries, deduces, protectionism, overwhelmed,
# Nearest to who: he, now, she, which, often, still, adamant, rower,
# Nearest to about: seele, convicted, agnostics, regarding, cynic, wildcat, jeane, quimby,
# Nearest to four: six, five, seven, eight, three, zero, two, nine,
# Nearest to by: through, denominated, from, gandhi, with, in, colloidal, be,
# Nearest to has: had, have, is, was, since, dom, contains, mudslides,
# Nearest to the: their, this, any, each, its, another, a, cara,
# Nearest to during: after, before, until, in, within, crucially, since, at,
# Nearest to to: would, leet, will, can, shall, cannot, stoneman, noises,
# Nearest to have: had, has, were, are, be, having, shevat, include,
# Average loss at step 72000: 3.374131
# Average loss at step 74000: 3.350069
# Average loss at step 76000: 3.319266
# Average loss at step 78000: 3.351626
# Average loss at step 80000: 3.379382
# Nearest to such: well, these, known, certain, including, many, rehabilitation, regarded,
# Nearest to use: collection, lack, fairs, support, concept, teleport, choice, imitate,
# Nearest to had: have, has, were, was, having, been, bierce, eritrean,
# Nearest to also: now, often, still, which, never, sometimes, generally, ammo,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, now, typically,
# Nearest to as: including, lans, insecticides, conses, broader, jagged, defies, became,
# Nearest to states: kingdom, nations, state, missiles, countries, saudi, deduces, us,
# Nearest to who: he, she, which, still, often, aise, never, now,
# Nearest to about: convicted, wildcat, over, seele, capitulated, regarding, barrow, approximately,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to by: through, with, schuschnigg, gandhi, when, ultrasound, from, gains,
# Nearest to has: had, have, is, was, having, since, dom, contains,
# Nearest to the: its, this, their, his, each, another, paleocene, frottage,
# Nearest to during: after, in, before, until, when, within, at, following,
# Nearest to to: would, will, leet, macmillan, magnentius, may, could, ais,
# Nearest to have: had, has, are, were, having, be, include, produce,
# Average loss at step 82000: 3.406228
# Average loss at step 84000: 3.408846
# Average loss at step 86000: 3.390463
# Average loss at step 88000: 3.358123
# Average loss at step 90000: 3.362850
# Nearest to such: well, known, these, many, including, certain, described, regarded,
# Nearest to use: support, collection, lack, storey, belief, choice, teleport, most,
# Nearest to had: has, have, was, were, having, since, generis, eritrean,
# Nearest to also: now, often, still, which, generally, sometimes, never, commonly,
# Nearest to often: usually, sometimes, commonly, frequently, generally, widely, typically, now,
# Nearest to as: lir, insecticides, jagged, enfant, including, papen, lansing, became,
# Nearest to states: kingdom, nations, us, countries, missiles, overwhelmed, state, topics,
# Nearest to who: she, he, often, which, still, now, they, aise,
# Nearest to about: regarding, seele, convicted, cynic, wildcat, agnostics, over, fethry,
# Nearest to four: seven, five, three, eight, six, two, nine, zero,
# Nearest to by: through, with, schuschnigg, when, stillman, using, colloidal, and,
# Nearest to has: had, have, is, was, having, contains, since, hutchinson,
# Nearest to the: its, their, his, atomism, this, a, any, danneskj,
# Nearest to during: after, in, before, until, within, through, while, despite,
# Nearest to to: would, will, towards, stoneman, ais, apostasy, cannot, establishes,
# Nearest to have: had, has, were, are, having, be, include, accept,
# Average loss at step 92000: 3.395403
# Average loss at step 94000: 3.251632
# Average loss at step 96000: 3.362272
# Average loss at step 98000: 3.243599
# Average loss at step 100000: 3.358873
# Nearest to such: well, known, many, including, these, certain, specific, seen,
# Nearest to use: support, collection, lack, fairs, cause, most, belief, imitate,
# Nearest to had: has, have, were, was, having, generis, been, since,
# Nearest to also: now, sometimes, still, never, often, generally, actually, commonly,
# Nearest to often: usually, sometimes, commonly, generally, frequently, typically, actually, widely,
# Nearest to as: limes, attendees, enfant, like, although, loomis, jagged, frontal,
# Nearest to states: nations, kingdom, countries, us, state, missiles, overwhelmed, saudi,
# Nearest to who: he, she, never, often, still, which, eritrean, louth,
# Nearest to about: seele, convicted, jeane, regarding, over, wildcat, approximately, clouds,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to by: when, through, using, groening, denominated, stillman, belgrano, gandhi,
# Nearest to has: had, have, is, was, since, contains, having, maintains,
# Nearest to the: their, its, his, a, some, your, our, her,
# Nearest to during: after, in, before, through, at, until, within, when,
# Nearest to to: will, would, cannot, could, should, leet, must, can,
# Nearest to have: had, has, were, are, having, include, contain, be,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
